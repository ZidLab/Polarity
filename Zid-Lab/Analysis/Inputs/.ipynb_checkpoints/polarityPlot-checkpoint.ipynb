# %%
import sys
import xlrd
import pandas as pd
import numpy as np
import os
from os.path import expanduser
import matplotlib.pyplot as plt
import matplotlib.style
import math
import csv

# %%
pwd = "Zid-Lab/Analysis/Polarity/Kyle/"
list_of_genes = {}
directory_list = [os.path.join(os.environ["HOME"],pwd+"Kyle_7_18_17/"), os.path.join(os.environ["HOME"],pwd+"Kyle_3_7_17/")]
pd_list = []

for directory in directory_list:
    count=0
    for root,dirs,files in os.walk(directory):
        for file in files:
            if file.endswith(".csv"):
                pd_list.append(pd.read_csv(os.path.join(directory, file), delimiter=",", header=0))
                label = file.split("_S")
                for name in pd_list[count]["Name"]:
                    if name not in list_of_genes:
                        list_of_genes[name] = label[0]+ ":" + str(pd_list[count].loc[pd_list[count]["Name"] == name, "PolarityPerGene"].item()) +";"
                    else:
                        list_of_genes[name] = list_of_genes[name]+label[0] + ":" + str(pd_list[count].loc[pd_list[count]["Name"] == name, "PolarityPerGene"].item()) +";"
                count = count + 1
print(list_of_genes)
# Out:
# {'YBR054W': 'ado1_5D_FP:0.44015444015444016;ado15DFP:0.44015444015444016;ado11DFP:0.4517374517374517;', 'YBR078W': 'ado1_5D_FP:0.08170310701956271;ado15DFP:0.08170310701956271;', 'YBR296C': 'ado1_5D_FP:0.4322132097334878;ado15DFP:0.4322132097334878;ado11DFP:0.589803012746234;', 'YCR005C': 'ado1_5D_FP:0.17485549132947978;ado15DFP:0.17485549132947978;', 'YGR192C': 'ado1_5D_FP:0.338;ado15DFP:0.338;', 'YKR039W': 'ado1_5D_FP:0.7204419889502762;ado15DFP:0.7204419889502762;', 'YMR092C': 'ado1_5D_FP:-0.5413737155219037;ado15DFP:-0.5413737155219037;', 'YMR217W': 'ado1_5D_FP:-0.3362887903736542;ado15DFP:-0.3362887903736542;', 'YNL104C': 'ado1_5D_FP:0.7721655024180548;ado15DFP:0.7721655024180548;', 'YNL327W': 'ado1_5D_FP:-0.3105212663895107;ado15DFP:-0.3105212663895107;', 'YOL006C': 'ado1_5D_FP:0.8874945910861101;ado15DFP:0.8874945910861101;', 'YPL159C': 'ado1_5D_FP:0.6094364351245085;ado15DFP:0.6094364351245085;', 'YPL265W': 'ado1_5D_FP:0.4978118161925602;ado15DFP:0.4978118161925602;', 'YBR072
# ...

# %%
#Convert to a dataframe
csv_columns = ['Name','PolarityPerGene']
combined_data = pd.DataFrame(list_of_genes.items(), columns=csv_columns)
combined_data
# Out:
#          Name                                    PolarityPerGene
# 0     YBR054W  ado1_5D_FP:0.44015444015444016;ado15DFP:0.4401...
# 1     YBR078W  ado1_5D_FP:0.08170310701956271;ado15DFP:0.0817...
# 2     YBR296C  ado1_5D_FP:0.4322132097334878;ado15DFP:0.43221...
# 3     YCR005C  ado1_5D_FP:0.17485549132947978;ado15DFP:0.1748...
# 4     YGR192C                   ado1_5D_FP:0.338;ado15DFP:0.338;
# 5     YKR039W  ado1_5D_FP:0.7204419889502762;ado15DFP:0.72044...
# 6     YMR092C  ado1_5D_FP:-0.5413737155219037;ado15DFP:-0.541...
# 7     YMR217W  ado1_5D_FP:-0.3362887903736542;ado15DFP:-0.336...
# 8     YNL104C  ado1_5D_FP:0.7721655024180548;ado15DFP:0.77216...
# 9     YNL327W  ado1_5D_FP:-0.3105212663895107;ado15DFP:-0.310...
# 10    YOL006C  ado1_5D_FP:0.8874945910861101;ado15DFP:0.88749...
# 11    YPL159C  ado1_5D_FP:0.6094364351245085;ado15DFP:0.60943...
# 12    YPL265W  ado1_5D_FP:0.4978118161925602;ado15DFP:0.49781...
# ...

# %%
csv_file = "combined.csv"
combined_data.to_csv(csv_file)

# %%
def PlotPolarity(inputfolder):
    #Inputs
    ext = "csv"
    polcsv_list=[]
    datas = {}
    for root,dirs,files in os.walk(inputfolder):
        for file in files:
            if file.split('.')[-1] == ext and tags[0] in file:
                polcsv_list.append(polcsv_dir + file)
                datas[labels[0]] = pd.read_csv(polcsv_dir + file, sep=',', usecols=['Length','PolarityPerGene'])
            elif file.split('.')[-1] == ext and tags[1] in file:
                polcsv_list.append(polcsv_dir + file)
                datas[labels[1]] = pd.read_csv(polcsv_dir + file, sep=',', usecols=['Length','PolarityPerGene'])
            elif file.split('.')[-1] == ext and tags[2] in file:
                polcsv_list.append(polcsv_dir + file)
                datas[labels[2]] = pd.read_csv(polcsv_dir + file, sep=',', usecols=['Length','PolarityPerGene'])
            elif file.split('.')[-1] == ext and tags[3] in file:
                polcsv_list.append(polcsv_dir + file)
                datas[labels[3]] = pd.read_csv(polcsv_dir + file, sep=',', usecols=['Length','PolarityPerGene'])
            else:
                continue
    
    #Find consensus genes
    consensus = []
    for index in range(len(datas[labels[0]])):
        gene = datas[labels[0]]["Length"].iloc[index]
        if gene in datas[labels[1]]["Length"] and gene in datas[labels[1]]["Length"] and gene in datas[labels[3]]["Length"]:
            consensus.append(gene)
                
    for key in datas.keys():
        for length in datas[key]["Length"]:
            if length not in consensus:
                datas[key] = datas[key].drop(length)
                
    # Plot polarity distributions
    if plot:
        fig = plt.figure()
        fig.set_size_inches((10, 10))
        ax = plt.axes()
        for key in datas.keys():
            fit_y = datas[key]['PolarityPerGene'] - datas[labels[0]]['PolarityPerGene']
            ax.plot(consensus, fit_y, label=key+"-Logphase")
        plt.xlabel("# Gene Length")
        plt.ylabel("# Polarity of -GluXX-Logphase")
        plt.title("Polarity")
        plt.tight_layout()
        plt.show()
        plt.savefig(OUTPUT)

# %%
# All output files will be stored in a folder under SortedFiles
PlotPolarity(INPUT)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-021d8442aeef> in <module>
#       1 # All output files will be stored in a folder under SortedFiles
# ----> 2 PlotPolarity(INPUT)
#
# <ipython-input-3-6cb06e202f09> in PlotPolarity(inputfolder)
#      23     #Find consensus genes
#      24     consensus = []
# ---> 25     for index in range(len(datas[labels[0]])):
#      26         gene = datas[labels[0]]["Length"].iloc[index]
#      27         if gene in datas[labels[1]]["Length"] and gene in datas[labels[1]]["Length"] and gene in datas[labels[3]]["Length"]:
#
# KeyError: 'logphase'
